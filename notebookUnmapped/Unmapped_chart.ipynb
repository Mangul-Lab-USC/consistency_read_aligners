# %%
import pandas as pd
df = pd.read_csv('../unmapped/Fenal.csv')
df.set_index('Tool_Name')
df.head()
# Out:
#   Tool_Name  RU
# 0    Bowtie   1
# 1   Bowtie2   1
# 2       BWA   1
# 3     Blasr   0
# 4  Graphmap   1

# %%
plot = df.plot.pie(y= 'RU', figsize=(20, 20))
plot.legend(df.Tool_Name)
plot.figure.savefig("unmapped.png")
