# %%
import pandas as pd
df = pd.read_csv('../unmapped/flagReport.csv')
df.head()
# Out:
#   Flag  Count
# 0   XA      1
# 1   MD      7
# 2   NM     10
# 3   AS      7
# 4   XN      1

# %%
import seaborn as sns
g=sns.lmplot(data=df, x='Flag', y='Count', hue='Flag',aspect=4,fit_reg=False)
g.savefig("flag.png")
